# %%
import requests
import pandas as pd
import json

# %%
with open('./transcript/jl.html', "r") as f:
    html = f.read()

# %%
import html

# %%
import urllib

# %%
from bs4 import BeautifulSoup

with open("./transcript/jl.html", "r") as f:
    contents = f.read()
    soup = BeautifulSoup(contents, 'lxml')

# %%
soup.find('table')
# Out:
# <table class="no-border-table">
# <tbody><tr>
# <td class="col_lg_3 col_md_5 ng-hide" ng-show="errorMsg==''&amp;&amp;xslb=='yjs'"><a href="javascript:void(0);" ng-click="getYjscjxx()"><span id="yjscjxx" style="color:#000000;font-size:17px;">研究生成绩</span></a></td>
# <td class="col_lg_3 col_md_5" ng-show="errorMsg==''&amp;&amp;xslb!=='yjs'"><a href="javascript:void(0);" ng-click="getGPA()"><span id="gpa" style="color: rgb(0, 0, 0); font-size: 17px;">个人GPA</span></a></td>
# <td class="col_lg_3 col_md_5" ng-show="errorMsg==''&amp;&amp;xslb!=='yjs'&amp;&amp;bkscjxx.length&gt;0"><a href="javascript:void(0);" ng-click="getBkscjxx()"><span id="bkscjxx" style="color: rgb(143, 0, 11); font-size: 17px;">本科生成绩</span></a></td>
# <td class="col_lg_3 col_md_5 ng-hide" ng-show="errorMsg==''&amp;&amp;xslb!=='yjs'&amp;&amp;bksfscjxx.length&gt;0"><a href="javascript:void(0);" ng-click="getBksfscjxx()"><span id="bksfscjxx" style="color:#000000;font-size:17px;">辅双成绩</span></a></td>
# ...

# %%
soup.body.prettify()
# Out:
# '<body class="ng-app:portal ng-scope" data-gr-c-s-loaded="true" id="ng-app" ng-app="portal" ng-controller="mainController">\n <!-- ngView:  -->\n <div class="ng-scope" ng-view="" style="min-height:556px;">\n  <header class="header" headerlogintpl="" ng-init="load()" ng-show="accessFromApp!==\'是\'">\n   <section>\n    <div class="topLine">\n    </div>\n    <section class="subNav">\n     <section class="ssubNav">\n      <ul class="subNavLeft">\n       <li>\n        <a class="ng-binding" href="javascript:void(0)" ng-click="logout()">\n         李嘉轩 [退出]\n        </a>\n       </li>\n      </ul>\n      <ul class="subNavRight">\n       <li>\n        <a href="/portal2017/#/pub/life" target="_blank" title="校园指数">\n         <img src="./img/biz-icon-life-w.png" style="width:16px;padding-bottom:2px;vertical-align:middle;"/>\n        </a>\n       </li>\n       <li>\n        <a href="/portal2017/bizcenter/its/redirectToITS.do?modId=web" target="_blank">\n         网络\n        </a>\n       </li>\n  
# ...

# %%
    print(soup.h2)
    print(soup.head)
    print(soup.li)
